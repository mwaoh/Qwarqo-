# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the website to scrape
url = 'https://qwarqo.com/seemore/bedsitter'

# Send a GET request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Create a BeautifulSoup object from the response content
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the container that holds the property listings
    property_listings = soup.find_all('div', class_='col-6 col-sm-6 col-md-3 col-lg-2 col-xxl-2')

    # Set a counter variable to limit the number of properties to extract
    count = 0

    # Iterate over each property listing and extract relevant information
    for listing in property_listings:
        # Check if the desired number of properties has been extracted
        if count >= 10:
            break

        # Extract the property title
        title = listing.find('h6', class_='card-title m-1').text

        # Extract the property description
        description = listing.find('div', class_='card-body p-2').text

        # Extract the property price
        #price = listing.find('span', class_='price').text

        # Extract the property location
        #location = listing.find('span', class_='card-text text-muted').text

        # Print the extracted information
        print('Title:', title)
        print('Description:', description)
        #print('Price:', price)
       # print('Location:', location)
        print('-------------------')

        # Increment the counter
        count += 1
else:
    print('Failed to retrieve the website. Status code:', response.status_code)
# Out:
# Title: MAGIC STONE
#
#
# Description:
# MAGIC STONE
#
#
# BedSitter (1)
#  Kisumu,Mountain view
#  Ksh  7,000
#
# -------------------
# Title: POLYVIEW ESTATE
#
#
# Description:
# POLYVIEW ESTATE
#
#
# BedSitter (2)
#  Kisumu,Polyview estate
#  Ksh  5,000
#
# -------------------
# Title: MURUGURU BEDSITTER
#
#
# Description:
# MURUGURU BEDSITTER
#
#
# BedSitter (1)
#  Nyeri,Muruguru near Karuga sawmill
#  Ksh  4,500
#
# -------------------
# Title: BEDSITTER TO LET
#
#
# Description:
# BEDSITTER TO LET
#
#
# BedSitter (1)
#  Gataka,SKL PLAZA, Next to AIC Church
#  Ksh  10,000
#
# -------------------
# Title: BEDSITTERS IN HARDY
#
#
# Description:
# BEDSITTERS IN HARDY
#
#
# BedSitter (1)
#  Nairobi,Karen,Hardy ,Koitobos Road
#  Ksh  12,900
#
# -------------------
# Title: SUNRISE SUITES
#
#
# Description:
# SUNRISE SUITES
#
#
# BedSitter (1)
#  Ongata Rongai,Olekasasi road, Manna
#  Ksh  8,000
#
# -------------------
# Title: THE PEARL APARTMENT
#
#
# Description:
# THE PEARL APARTMENT
#
#
# BedSitter (5)
#  Karen,Gataka, Between Kericho and Sagomo
#  Ksh  8,500
#
# -------------------
# Title: CATHOLIC LANE RENTALS
#
#
# Description:
# CATHOLIC LANE RENTALS
#
#
# BedSitter (3)
#  Gataka,Catholic lane opposite police station
#  Ksh  6,000
#
# -------------------
# Title: APARTMENT IN VET
#
#
# Description:
# APARTMENT IN VET
#
#
# BedSitter (1)
#  Ngong,Bul
#  Ksh  8,000
#
# -------------------
# Title: LUCY'S APARTMENTS
#
#
# Description:
# LUCY'S APARTMENTS
#
#
# BedSitter (40)
#  Rongai,Umoja road
#  Ksh  8,000
#
# -------------------
