# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the website to scrape
url = 'https://qwarqo.com/seemore/bedroom'

# Send a GET request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Create a BeautifulSoup object from the response content
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the container that holds the property listings
    property_listings = soup.find_all('div', class_='col-6 col-sm-6 col-md-3 col-lg-2 col-xxl-2')

    # Set a counter variable to limit the number of properties to extract
    count = 0

    # Iterate over each property listing and extract relevant information
    for listing in property_listings:
        # Check if the desired number of properties has been extracted
        if count >= 10:
            break

        # Extract the property title
        title = listing.find('h6', class_='card-title m-1').text

        # Extract the property description
        description = listing.find('div', class_='card-body p-2').text

        # Extract the property price
        #price = listing.find('span', class_='price').text

        # Extract the property location
        #location = listing.find('span', class_='card-text text-muted').text

        # Print the extracted information
        print('Title:', title)
        print('Description:', description)
        #print('Price:', price)
       # print('Location:', location)
        print('-------------------')

        # Increment the counter
        count += 1
else:
    print('Failed to retrieve the website. Status code:', response.status_code)
# Out:
# Title: TREELINE APARTMENT
#
#
# Description:
# TREELINE APARTMENT
#
#
# 2 Bedroom (1)
#  Kisumu,Nyamasaria
#  Ksh  27,000
#
# -------------------
# Title: LAKE VIEW APARTMENTS
#
#
# Description:
# LAKE VIEW APARTMENTS
#
#
# 4+ Bedrooms (1)
#  Kisumu,Milimani estate
#  Ksh  150,000
#
# -------------------
# Title: DAGORETTI CORNER, SUNA 1 ESTATE
#
#
# Description:
# DAGORETTI CORNER, SUNA 1 ESTATE
#
#
# 3 Bedroom (1)
#  Nairobi,Dagoretti Corner, Suna 1 Estate
#  Ksh  25,000
#
# -------------------
# Title: SIRNICS PROPERTY
#
#
# Description:
# SIRNICS PROPERTY
#
#
# 2 Bedroom (1)
#  Kisumu,Nyamasaria
#  Ksh  20,000
#
# -------------------
# Title: LOLWE ESTATE
#
#
# Description:
# LOLWE ESTATE
#
#
# 2 Bedroom (1)
#  Kisumu,Lolwe
#  Ksh  16,000
#
# -------------------
# Title: ARROWS DEN APARTMENTS, GITARU
#
#
# Description:
# ARROWS DEN APARTMENTS, GITARU
#
#
# 1 Bedroom (5)
#  Nairobi,GITARU, OFF NAIROBI-NAKURU HIGHWAY
#  Ksh  18,000
#
# -------------------
# Title: P.C.E.A RONGAI
#
#
# Description:
# P.C.E.A RONGAI
#
#
# 3 Bedroom (20)
#  Rongai,1
#  Ksh  6,000,000
#
# -------------------
# Title: P.C.E.A RONGAI
#
#
# Description:
# P.C.E.A RONGAI
#
#
# 3 Bedroom (1)
#  Rongai,1
#  Ksh  6,000,000
#
# -------------------
# Title: BUXTON POINT APARTMENTS
#
#
# Description:
# BUXTON POINT APARTMENTS
#
#
# 2 Bedroom (1)
#  Mombasa,Buxton Estate, Buxton, Tom Mboya Rd, Mombasa
#  Ksh  4,400,000
#
# -------------------
# Title: 4BR VILLA AT METRO VILLAS- BURU BURU
#
#
# Description:
# 4BR VILLA AT METRO VILLAS- BURU BURU
#
#
# 4+ Bedrooms (1)
#  Nairobi,Buruburu
#  Ksh  25,000,000
#
# -------------------
