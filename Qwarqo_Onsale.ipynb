# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the website to scrape
url = 'https://www.qwarqo.com/Onsale'

# Send a GET request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Create a BeautifulSoup object from the response content
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the container that holds the property listings
    property_listings = soup.find_all('div', class_='col col-sm-6 col-md-4 col-lg-3 col-xl-3 mt-2')

    # Set a counter variable to limit the number of properties to extract
    count = 0

    # Iterate over each property listing and extract relevant information
    for listing in property_listings:
        # Check if the desired number of properties has been extracted
        if count >= 10:
            break

        # Extract the property title
        title = listing.find('h5', class_='card-title').text

        # Extract the property description
        description = listing.find('div', class_='card-body').text

        # Extract the property price
        #price = listing.find('span', class_='price').text

        # Extract the property location
        #location = listing.find('span', class_='card-text text-muted').text

        # Print the extracted information
        print('Title:', title)
        print('Description:', description)
        #print('Price:', price)
       # print('Location:', location)
        print('-------------------')

        # Increment the counter
        count += 1
else:
    print('Failed to retrieve the website. Status code:', response.status_code)
# Out:
# Title: 4Br Maisonette  on sale in Athi River
# Description:
# 4Br Maisonette  on sale in Athi River
# Athi River,Athi River
# Buy
#
# -------------------
# Title: Alba Gardens Apartments in Kilimani
# Description:
# Alba Gardens Apartments in Kilimani
# Nairobi,Kilimani
# Buy
#
# -------------------
# Title: King's Serenity
# Description:
# King's Serenity
# Nairobi,Ongata Rongai
# Buy
#
# -------------------
# Title: 4Br Maisonette with a dsq at Mona Park
# Description:
# 4Br Maisonette with a dsq at Mona Park
# Ruiru,Kimbo
# Buy
#
# -------------------
# Title: 7 Bedroom House For Sale available at Elgon View
# Description:
# 7 Bedroom House For Sale available at Elgon View
# Eldoret,Elgon View(near Fountain Hospital) in Eldoret
# Buy
#
# -------------------
# Title: 4br VILLA AT METRO VILLAS- Buru Buru
# Description:
# 4br VILLA AT METRO VILLAS- Buru Buru
# Nairobi,Buruburu
# Buy
#
# -------------------
# Title: 3Br Master ensuite Apartment in Lavington
# Description:
# ...
